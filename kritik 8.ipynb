# %% [markdown]
# # Question 4.a

# %%
def gradient_descent(x0, y0,f, grad_f, alpha, num_iterations):
    """
    Parameters:
    x0, y0: Initial point for the descent.
    f: a function of two variables
    grad_f: the gradient of f
    alpha: Learning rate.
    num_iterations: Number of iterations to perform.
    Returns:
    (x, y): The coordinates of the final point after gradient descent.
    """
    x, y = x0, y0 # Initialize x and y with the initial point
    for i in range(num_iterations):
    # obtain the gradient of f at (x, y)
        grad_x, grad_y = grad_f(x,y) # my code
    # Update x and y by taking a step in the
    # opposite direction of the gradient
        x = x- alpha* grad_x# x minus the learning rate times the x gradient of descent
        y = y- alpha* grad_y # y minus the learning rate times the y gradient of descent
    return x, y

# %% [markdown]
# # Question 4.b

# %%
# test case one: (x0, y0) = (0.1, 0.1), α = 0.1, max iterations = 10
def fun_1(x,y):
    return x**2+y**2
    
def grad_f_1(x,y):
    grad_x = 2*x # the partail derivative in respect to x of the function 
    grad_y = 2*y # the partial derivative in respect to y of the fuction 
    return grad_x, grad_y
gradient_descent(0.1, 0.1, fun_1 , grad_f_1 , 0.1, 10)
# Out:
# (0.010737418240000003, 0.010737418240000003)

# %%
# test case two: (x0, y0) = (−1, 1), α = 0.01, max iterations = 100.
gradient_descent(-1, 1, fun_1 , grad_f_1 , 0.01, 100)
# Out:
# (-0.13261955589475316, 0.13261955589475316)

# %% [markdown]
# # Question 4.c

# %%
import numpy as np
def fun_2(x,y):
    return 1-np.exp(-x**2-(y-2)**2)-2*np.exp(-x**2-(y+2)**2)

def grad_f_2(x,y):
    grad_x = (2*x*np.exp(-x**2-(y-2)**2))+(4*x*np.exp(-x**2-(y+2)**2))
              # the derivative with respect to x
    grad_y = 2 * (y - 2) * np.exp(-x**2 - (y - 2)**2) + 4 * (y + 2) * np.exp(-x**2 - (y + 2)**2)
    return grad_x, grad_y
'''
and apply your gradient descent to the following test cases:
• (x0, y0) = (0, 1), α = 0.01, max iterations = 10000
• (x0, y0) = (0, −1), α = 0.01, max iterations = 10000.
What do you notice?
'''

import numpy as np
from mpl_toolkits import mplot3d #for 3D plots
import matplotlib.pyplot as plt #usual matplotlib
# %matplotlib widget
X=np.linspace(-5,5,100)
Y=np.linspace(-5,5,100)
x,y=np.meshgrid(X,Y)
z= 1-np.exp(-x**2-(y-2)**2)-2*np.exp(-x**2-(y+2)**2)
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none')
#x,y z are variable names.
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # I notice that the graph has two minimas, one local and one global these minimmas seem to be the ones from question 4b.
# # The local minima is from test case one and therefore located at (0.010737418240000003, 0.010737418240000003).
# # The global minima is from test case two and therefore located at (-0.13261955589475316, 0.13261955589475316).
